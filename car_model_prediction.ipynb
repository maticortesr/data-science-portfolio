# %% [markdown]
# <a href="https://colab.research.google.com/github/maticortesr/data-science-portfolio/blob/master/car_model_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-66e2ddf2-8538-4e6a-8344-f94fc4c98ae6" name="files[]" multiple disabled />
#      <output id="result-66e2ddf2-8538-4e6a-8344-f94fc4c98ae6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"maticortes","key":"e5f37c29a8a5de26504c4236573db5dc"}'}

# %%
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 66 Feb 27 13:10 kaggle.json

# %%
# !pip install -q kaggle

# %%
# !ls
# Out:
# kaggle.json  sample_data

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                          title                                                size  lastUpdated          downloadCount
# -----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# ronitf/heart-disease-uci                                     Heart Disease UCI                                     3KB  2018-06-25 11:33:56          10309
# russellyates88/suicide-rates-overview-1985-to-2016           Suicide Rates Overview 1985 to 2016                 396KB  2018-12-01 19:18:25           7298
# lava18/google-play-store-apps                                Google Play Store Apps                                2MB  2019-02-03 13:55:47          38379
# karangadiya/fifa19                                           FIFA 19 complete player dataset                       2MB  2018-12-21 03:52:59          10429
# ...

# %%
# !kaggle datasets download -d jutrera/stanford-car-dataset-by-classes-folder
# Out:
# ...
# 100% 1.82G/1.82G [00:29<00:00, 83.9MB/s]
# 100% 1.82G/1.82G [00:29<00:00, 65.6MB/s]

# %%
# !ls
# Out:
# kaggle.json  sample_data  stanford-car-dataset-by-classes-folder.zip

# %%
# !unzip "*.zip"
# Out:
# Archive:  stanford-car-dataset-by-classes-folder.zip
#   inflating: car_data.zip
#   inflating: anno_train.csv
#   inflating: names.csv
#   inflating: anno_test.csv

# %%
# !unzip "car_data.zip"

# %%
# !ls car_data/train/
# Out:
# 'Acura Integra Type R 2001'
# 'Acura RL Sedan 2012'
# 'Acura TL Sedan 2012'
# 'Acura TL Type-S 2008'
# 'Acura TSX Sedan 2012'
# 'Acura ZDX Hatchback 2012'
# 'AM General Hummer SUV 2000'
# 'Aston Martin V8 Vantage Convertible 2012'
# 'Aston Martin V8 Vantage Coupe 2012'
# 'Aston Martin Virage Convertible 2012'
# 'Aston Martin Virage Coupe 2012'
# 'Audi 100 Sedan 1994'
# 'Audi 100 Wagon 1994'
# 'Audi A5 Coupe 2012'
# 'Audi R8 Coupe 2012'
# 'Audi RS 4 Convertible 2008'
# 'Audi S4 Sedan 2007'
# 'Audi S4 Sedan 2012'
# 'Audi S5 Convertible 2012'
# 'Audi S5 Coupe 2012'
# 'Audi S6 Sedan 2011'
# 'Audi TT Hatchback 2011'
# 'Audi TT RS Coupe 2012'
# 'Audi TTS Coupe 2012'
# 'Audi V8 Sedan 1994'
# 'Bentley Arnage Sedan 2009'
# 'Bentley Continental Flying Spur Sedan 2007'
# 'Bentley Continental GT Coupe 2007'
# 'Bentley Continental GT Coupe 2012'
# 'Bentley Continental Supersports Conv. Convertible 2012'
# 'Bentley Mulsanne Sedan 2011'
# 'BMW 1 Series Convertible 2012'
# 'BMW 1 Series Coupe 2012'
# ...

# %%
# Out:
# anno_test.csv	car_data.zip  sample_data
# anno_train.csv	kaggle.json   stanford-car-dataset-by-classes-folder.zip
# car_data	names.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %%
img=mpimg.imread('car_data/train/Acura Integra Type R 2001/06538.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
names = pd.read_csv('names.csv', header=None)
anno_train = pd.read_csv('anno_train.csv', header=None)
anno_test = pd.read_csv('anno_test.csv', header=None)

# %%
names.head()
# Out:
#                             0
# 0  AM General Hummer SUV 2000
# 1         Acura RL Sedan 2012
# 2         Acura TL Sedan 2012
# 3        Acura TL Type-S 2008
# 4        Acura TSX Sedan 2012

# %%
anno_train.head()
# Out:
#            0    1    2     3     4    5
# 0  00001.jpg   39  116   569   375   14
# 1  00002.jpg   36  116   868   587    3
# 2  00003.jpg   85  109   601   381   91
# 3  00004.jpg  621  393  1484  1096  134
# 4  00005.jpg   14   36   133    99  106
